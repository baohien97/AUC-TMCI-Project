# %%
import requests
import pandas as pd
from pandas_datareader import data

# %%
#https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
#https://github.com/rsvp/fecon235/issues/7
#https://www.learndatasci.com/tutorials/python-finance-part-yahoo-finance-api-pandas-matplotlib/
#https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
#https://github.com/kartik-joshi/Stock-predection
#https://snap.stanford.edu/data/twitter7.html
#https://github.com/shaypal5/awesome-twitter-data
#https://www.kaggle.com/kazanova/sentiment140

# %%
#def get_google_data(start_date, end_date, *args):
key = "T9Y563WVTXPFUZT5" #alpha_vantage

# %%
start_date = '2018-01-01'
end_date = '2018-12-01'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader('AAPL', 'iex', start_date, end_date)

# %%
panel_data
# Out:
#                 open      high       low     close    volume
# date
# 2018-01-02  167.6431  169.7514  166.7564  169.7120  25555934
# 2018-01-03  169.9780  171.9682  169.4165  169.6825  29517899
# 2018-01-04  169.9879  170.9041  169.5347  170.4707  22434597
# 2018-01-05  170.8746  172.7760  170.4904  172.4115  23660018
# 2018-01-08  171.7711  173.0125  171.3573  171.7711  20567766
# 2018-01-09  171.9682  172.4706  170.8450  171.7514  21583997
# 2018-01-10  170.5987  171.7219  170.4411  171.7120  23959895
# 2018-01-11  172.0076  172.8929  171.9091  172.6874  18667729
# 2018-01-12  173.5741  174.7366  173.0519  174.4706  25418080
# 2018-01-16  175.2686  176.7366  173.5346  173.5839  29565947
# 2018-01-17  173.5445  176.5986  172.4805  176.4509  34386836
# 2018-01-18  176.7169  177.4361  175.6134  176.6085  31193352
# 2018-01-19  175.9681  176.9238  174.7859  175.8203  32425067
# 2018-01-22  174.6775  175.1504  173.9894  174.3819  27108551
# ...
